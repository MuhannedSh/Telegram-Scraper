# %%
# !pip install telethon
# Out:
# Requirement already satisfied: telethon in /usr/local/lib/python3.10/dist-packages (1.37.0)
# Requirement already satisfied: pyaes in /usr/local/lib/python3.10/dist-packages (from telethon) (1.6.1)
# Requirement already satisfied: rsa in /usr/local/lib/python3.10/dist-packages (from telethon) (4.9)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.10/dist-packages (from rsa->telethon) (0.6.1)

# %%
# Initial imports
from datetime import datetime, timezone
import pandas as pd
import time
import json
import re

# Telegram imports
from telethon.sync import TelegramClient

# Google Colab imports
from google.colab import files

# Setup / change only the first time you use it
username = 'Muhannedbsh'  # Your Telegram account username (just 'abc123', not '@')
phone = '+970597001756'  # Your Telegram account phone number (ex: '+5511999999999')
api_id = '28907833'  # Your API ID, it can be only generated from https://my.telegram.org/apps
api_hash = '3d1a83db7108fe233a36f5c54a2878dc'  # Your API hash, also from https://my.telegram.org/apps

# %%
# Setup / change every time to define scraping parameters
channels = [
    '@meshheek',
    '@fajernews',
    '@ramallahnew',
    '@Almustashaar',


]
File = 'excel'
# Here you put the name of the channel or group that you want to scrape
# As an example, play: '@LulanoTelegram' or 'https://t.me/LulanoTelegram'
# Do not use: 'https://web.telegram.org/a/#-1001249230829' or '-1001249230829'

d_min = 20  # Start day (inclusive)
m_min = 9  # Start month
y_min = 2024  # Start year
d_max = 1  # End day (exclusive)
m_max = 10  # End month
y_max = 2024  # End year
file_name = 'TG10_days_data_Analysis'  # Output file name
key_search = ''  # Keyword to search, leave empty if not needed
max_t_index = 1000000  # Maximum number of messages to scrape
time_limit = 6 * 60 * 60  # Timeout in hours (*seconds)

# %%
data = []  # List to store scraped data
t_index = 0  # Tracker for the number of messages processed
start_time = time.time()  # Record the start time for the scraping session

# Function to remove invalid XML characters from text
def remove_unsupported_characters(text):
    valid_xml_chars = (
        "[^\u0009\u000A\u000D\u0020-\uD7FF\uE000-\uFFFD"
        "\U00010000-\U0010FFFF]"
    )
    cleaned_text = re.sub(valid_xml_chars, '', text)
    return cleaned_text

# Function to format time in days, hours, minutes, and seconds
def format_time(seconds):
    days = seconds // 86400
    hours = (seconds % 86400) // 3600
    minutes = (seconds % 3600) // 60
    seconds = seconds % 60
    return f'{int(days):02}:{int(hours):02}:{int(minutes):02}:{int(seconds):02}'

# Function to print progress of the scraping process
def print_progress(t_index, message_id, start_time, max_t_index):
    elapsed_time = time.time() - start_time
    current_progress = t_index / (t_index + message_id) if (t_index + message_id) <= max_t_index else t_index / max_t_index
    percentage = current_progress * 100
    estimated_total_time = elapsed_time / current_progress
    remaining_time = estimated_total_time - elapsed_time

    elapsed_time_str = format_time(elapsed_time)
    remaining_time_str = format_time(remaining_time)

    print(f'Progress: {percentage:.2f}% | Elapsed Time: {elapsed_time_str} | Remaining Time: {remaining_time_str}')

# Scraping process
for channel in channels:
    if t_index >= max_t_index:
        break

    if time.time() - start_time > time_limit:
        break

    loop_start_time = time.time()

    try:
        c_index = 0
        async with TelegramClient(username, api_id, api_hash) as client:
            async for message in client.iter_messages(channel, search=key_search):
                try:
                    if datetime(y_min, m_min, d_min, tzinfo=timezone.utc) < message.date <= datetime(y_max, m_max, d_max, tzinfo=timezone.utc):

                        # Process comments of the message
                        comments_list = []
                        try:
                            async for comment_message in client.iter_messages(channel, reply_to=message.id):
                                comment_text = comment_message.text.replace("'", '"')

                                comment_media = 'True' if comment_message.media else 'False'

                                comment_emoji_string = ''
                                if comment_message.reactions:
                                    for reaction_count in comment_message.reactions.results:
                                        emoji = reaction_count.reaction.emoticon
                                        count = str(reaction_count.count)
                                        comment_emoji_string += emoji + " " + count + " "

                                comment_date_time = comment_message.date.strftime('%Y-%m-%d %H:%M:%S')

                                comments_list.append({
                                    'Type': 'comment',
                                    'Comment Group': channel,
                                    'Comment Author ID': comment_message.sender_id,
                                    'Comment Content': comment_text,
                                    'Comment Date': comment_date_time,
                                    'Comment Message ID': comment_message.id,
                                    'Comment Author': comment_message.post_author,
                                    'Comment Views': comment_message.views,
                                    'Comment Reactions': comment_emoji_string,
                                    'Comment Shares': comment_message.forwards,
                                    'Comment Media': comment_media,
                                    'Comment Url': f'https://t.me/{channel}/{message.id}?comment={comment_message.id}'.replace('@', ''),
                                })
                        except Exception as e:
                            comments_list = []
                            print(f'Error processing comments: {e}')

                        # Process the main message
                        media = 'True' if message.media else 'False'

                        emoji_string = ''
                        if message.reactions:
                            for reaction_count in message.reactions.results:
                                emoji = reaction_count.reaction.emoticon
                                count = str(reaction_count.count)
                                emoji_string += emoji + " " + count + " "

                        date_time = message.date.strftime('%Y-%m-%d %H:%M:%S')
                        cleaned_content = remove_unsupported_characters(message.text)
                        cleaned_comments_list = remove_unsupported_characters(json.dumps(comments_list))

                        data.append({
                            'Type': 'text',
                            'Group': channel,
                            'Author ID': message.sender_id,
                            'Content': cleaned_content,
                            'Date': date_time,
                            'Message ID': message.id,
                            'Author': message.post_author,
                            'Views': message.views,
                            'Reactions': emoji_string,
                            'Shares': message.forwards,
                            'Media': media,
                            'Url': f'https://t.me/{channel}/{message.id}'.replace('@', ''),
                            'Comments List': cleaned_comments_list,
                        })

                        c_index += 1
                        t_index += 1

                        # Print progress
                        print(f'{"-" * 80}')
                        print_progress(t_index, message.id, start_time, max_t_index)
                        current_max_id = min(c_index + message.id, max_t_index)
                        print(f'From {channel}: {c_index:05} contents of {current_max_id:05}')
                        print(f'Id: {message.id:05} / Date: {date_time}')
                        print(f'Total: {t_index:05} contents until now')
                        print(f'{"-" * 80}\n\n')

                        if t_index % 1000 == 0:
                            if File == 'parquet':
                                backup_filename = f'backup_{file_name}_until_{t_index:05}_{channel}_ID{message.id:07}.parquet'
                                pd.DataFrame(data).to_parquet(backup_filename, index=False)
                            elif File == 'excel':
                                backup_filename = f'backup_{file_name}_until_{t_index:05}_{channel}_ID{message.id:07}.xlsx'
                                pd.DataFrame(data).to_excel(backup_filename, index=False)

                        if t_index >= max_t_index:
                            break

                        if time.time() - start_time > time_limit:
                            break

                    elif message.date < datetime(y_min, m_min, d_min, tzinfo=timezone.utc):
                        break

                except Exception as e:
                    print(f'Error processing message: {e}')

        print(f'\n\n##### {channel} was ok with {c_index:05} posts #####\n\n')

        df = pd.DataFrame(data)
        if File == 'parquet':
            partial_filename = f'complete_{channel}_in_{file_name}_until_{t_index:05}.parquet'
            df.to_parquet(partial_filename, index=False)
        elif File == 'excel':
            partial_filename = f'complete_{channel}_in_{file_name}_until_{t_index:05}.xlsx'
            df.to_excel(partial_filename, index=False)
        # files.download(partial_filename)

    except Exception as e:
        print(f'{channel} error: {e}')

    loop_end_time = time.time()
    loop_duration = loop_end_time - loop_start_time

    if loop_duration < 60:
        time.sleep(60 - loop_duration)

print(f'\n{"-" * 50}\n#Concluded! #{t_index:05} posts were scraped!\n{"-" * 50}\n\n\n\n')
df = pd.DataFrame(data)
if File == 'parquet':
    final_filename = f'FINAL_{file_name}_with_{t_index:05}.parquet'
    df.to_parquet(final_filename, index=False)
elif File == 'excel':
    final_filename = f'FINAL_{file_name}_with_{t_index:05}.xlsx'
    df.to_excel(final_filename, index=False)
files.download(final_filename)
# Out:
# Streaming output truncated to the last 5000 lines.
# Id: 42468 / Date: 2024-09-26 12:24:02
# Total: 04884 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.32% | Elapsed Time: 00:01:09:20 | Remaining Time: 00:10:02:49
# From @Almustashaar: 00401 contents of 42868
# Id: 42467 / Date: 2024-09-26 12:20:55
# Total: 04885 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.32% | Elapsed Time: 00:01:09:20 | Remaining Time: 00:10:02:43
# From @Almustashaar: 00402 contents of 42868
# Id: 42466 / Date: 2024-09-26 12:16:49
# Total: 04886 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.32% | Elapsed Time: 00:01:09:21 | Remaining Time: 00:10:02:37
# From @Almustashaar: 00403 contents of 42868
# Id: 42465 / Date: 2024-09-26 12:14:47
# Total: 04887 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.32% | Elapsed Time: 00:01:09:21 | Remaining Time: 00:10:02:30
# From @Almustashaar: 00404 contents of 42867
# Id: 42463 / Date: 2024-09-26 12:11:38
# Total: 04888 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.33% | Elapsed Time: 00:01:09:21 | Remaining Time: 00:10:02:25
# From @Almustashaar: 00405 contents of 42867
# Id: 42462 / Date: 2024-09-26 11:58:00
# Total: 04889 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.33% | Elapsed Time: 00:01:09:21 | Remaining Time: 00:10:02:19
# From @Almustashaar: 00406 contents of 42867
# Id: 42461 / Date: 2024-09-26 10:38:35
# Total: 04890 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.33% | Elapsed Time: 00:01:09:22 | Remaining Time: 00:10:02:12
# From @Almustashaar: 00407 contents of 42866
# Id: 42459 / Date: 2024-09-26 08:55:27
# Total: 04891 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.33% | Elapsed Time: 00:01:09:22 | Remaining Time: 00:10:02:06
# From @Almustashaar: 00408 contents of 42866
# Id: 42458 / Date: 2024-09-26 08:47:31
# Total: 04892 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.33% | Elapsed Time: 00:01:09:22 | Remaining Time: 00:10:02:01
# From @Almustashaar: 00409 contents of 42866
# Id: 42457 / Date: 2024-09-26 08:14:55
# Total: 04893 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.34% | Elapsed Time: 00:01:09:23 | Remaining Time: 00:10:01:55
# From @Almustashaar: 00410 contents of 42866
# Id: 42456 / Date: 2024-09-26 07:59:11
# Total: 04894 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.34% | Elapsed Time: 00:01:09:23 | Remaining Time: 00:10:01:49
# From @Almustashaar: 00411 contents of 42866
# Id: 42455 / Date: 2024-09-26 07:57:44
# Total: 04895 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.34% | Elapsed Time: 00:01:09:23 | Remaining Time: 00:10:01:43
# From @Almustashaar: 00412 contents of 42866
# Id: 42454 / Date: 2024-09-26 07:55:20
# Total: 04896 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.34% | Elapsed Time: 00:01:09:23 | Remaining Time: 00:10:01:37
# From @Almustashaar: 00413 contents of 42866
# Id: 42453 / Date: 2024-09-26 07:54:20
# Total: 04897 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.34% | Elapsed Time: 00:01:09:24 | Remaining Time: 00:10:01:32
# From @Almustashaar: 00414 contents of 42866
# Id: 42452 / Date: 2024-09-26 07:52:45
# Total: 04898 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.35% | Elapsed Time: 00:01:09:24 | Remaining Time: 00:10:01:26
# From @Almustashaar: 00415 contents of 42866
# Id: 42451 / Date: 2024-09-26 07:48:38
# Total: 04899 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.35% | Elapsed Time: 00:01:09:24 | Remaining Time: 00:10:01:19
# From @Almustashaar: 00416 contents of 42865
# Id: 42449 / Date: 2024-09-25 22:03:54
# Total: 04900 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.35% | Elapsed Time: 00:01:09:25 | Remaining Time: 00:10:01:14
# From @Almustashaar: 00417 contents of 42865
# Id: 42448 / Date: 2024-09-25 20:35:00
# Total: 04901 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.35% | Elapsed Time: 00:01:09:25 | Remaining Time: 00:10:01:08
# From @Almustashaar: 00418 contents of 42865
# Id: 42447 / Date: 2024-09-25 20:17:39
# Total: 04902 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.36% | Elapsed Time: 00:01:09:25 | Remaining Time: 00:10:01:02
# From @Almustashaar: 00419 contents of 42865
# Id: 42446 / Date: 2024-09-25 20:13:47
# Total: 04903 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.36% | Elapsed Time: 00:01:09:25 | Remaining Time: 00:10:00:56
# From @Almustashaar: 00420 contents of 42865
# Id: 42445 / Date: 2024-09-25 20:06:20
# Total: 04904 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.36% | Elapsed Time: 00:01:09:26 | Remaining Time: 00:10:00:50
# From @Almustashaar: 00421 contents of 42865
# Id: 42444 / Date: 2024-09-25 19:51:05
# Total: 04905 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.36% | Elapsed Time: 00:01:09:26 | Remaining Time: 00:10:00:45
# From @Almustashaar: 00422 contents of 42865
# Id: 42443 / Date: 2024-09-25 19:48:13
# Total: 04906 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.36% | Elapsed Time: 00:01:09:26 | Remaining Time: 00:10:00:39
# From @Almustashaar: 00423 contents of 42865
# Id: 42442 / Date: 2024-09-25 19:22:05
# Total: 04907 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.37% | Elapsed Time: 00:01:09:27 | Remaining Time: 00:10:00:38
# From @Almustashaar: 00424 contents of 42862
# Id: 42438 / Date: 2024-09-25 18:57:51
# Total: 04908 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.37% | Elapsed Time: 00:01:09:28 | Remaining Time: 00:10:00:32
# From @Almustashaar: 00425 contents of 42862
# Id: 42437 / Date: 2024-09-25 18:50:36
# Total: 04909 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.37% | Elapsed Time: 00:01:09:28 | Remaining Time: 00:10:00:26
# From @Almustashaar: 00426 contents of 42862
# Id: 42436 / Date: 2024-09-25 18:47:37
# Total: 04910 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.37% | Elapsed Time: 00:01:09:28 | Remaining Time: 00:10:00:21
# From @Almustashaar: 00427 contents of 42862
# Id: 42435 / Date: 2024-09-25 18:38:21
# Total: 04911 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.37% | Elapsed Time: 00:01:09:29 | Remaining Time: 00:10:00:15
# From @Almustashaar: 00428 contents of 42862
# Id: 42434 / Date: 2024-09-25 18:36:16
# Total: 04912 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.38% | Elapsed Time: 00:01:09:29 | Remaining Time: 00:10:00:09
# From @Almustashaar: 00429 contents of 42862
# Id: 42433 / Date: 2024-09-25 18:33:00
# Total: 04913 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.38% | Elapsed Time: 00:01:09:29 | Remaining Time: 00:10:00:05
# From @Almustashaar: 00430 contents of 42861
# Id: 42431 / Date: 2024-09-25 17:49:21
# Total: 04914 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.38% | Elapsed Time: 00:01:09:30 | Remaining Time: 00:09:59:59
# From @Almustashaar: 00431 contents of 42861
# Id: 42430 / Date: 2024-09-25 17:47:49
# Total: 04915 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.38% | Elapsed Time: 00:01:09:30 | Remaining Time: 00:09:59:54
# From @Almustashaar: 00432 contents of 42861
# Id: 42429 / Date: 2024-09-25 17:47:02
# Total: 04916 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.39% | Elapsed Time: 00:01:09:30 | Remaining Time: 00:09:59:48
# From @Almustashaar: 00433 contents of 42861
# Id: 42428 / Date: 2024-09-25 17:46:03
# Total: 04917 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.39% | Elapsed Time: 00:01:09:30 | Remaining Time: 00:09:59:42
# From @Almustashaar: 00434 contents of 42861
# Id: 42427 / Date: 2024-09-25 17:44:47
# Total: 04918 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.39% | Elapsed Time: 00:01:09:31 | Remaining Time: 00:09:59:36
# From @Almustashaar: 00435 contents of 42861
# Id: 42426 / Date: 2024-09-25 17:35:16
# Total: 04919 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.39% | Elapsed Time: 00:01:09:31 | Remaining Time: 00:09:59:32
# From @Almustashaar: 00436 contents of 42860
# Id: 42424 / Date: 2024-09-25 17:29:53
# Total: 04920 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.39% | Elapsed Time: 00:01:09:32 | Remaining Time: 00:09:59:26
# From @Almustashaar: 00437 contents of 42860
# Id: 42423 / Date: 2024-09-25 17:29:53
# Total: 04921 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.40% | Elapsed Time: 00:01:09:32 | Remaining Time: 00:09:59:21
# From @Almustashaar: 00438 contents of 42860
# Id: 42422 / Date: 2024-09-25 17:29:53
# Total: 04922 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.40% | Elapsed Time: 00:01:09:32 | Remaining Time: 00:09:59:15
# From @Almustashaar: 00439 contents of 42860
# Id: 42421 / Date: 2024-09-25 17:27:29
# Total: 04923 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.40% | Elapsed Time: 00:01:09:32 | Remaining Time: 00:09:59:09
# From @Almustashaar: 00440 contents of 42860
# Id: 42420 / Date: 2024-09-25 17:20:21
# Total: 04924 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.40% | Elapsed Time: 00:01:09:33 | Remaining Time: 00:09:59:04
# From @Almustashaar: 00441 contents of 42860
# Id: 42419 / Date: 2024-09-25 17:18:03
# Total: 04925 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.40% | Elapsed Time: 00:01:09:33 | Remaining Time: 00:09:58:58
# From @Almustashaar: 00442 contents of 42860
# Id: 42418 / Date: 2024-09-25 17:16:06
# Total: 04926 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.41% | Elapsed Time: 00:01:09:34 | Remaining Time: 00:09:58:54
# From @Almustashaar: 00443 contents of 42859
# Id: 42416 / Date: 2024-09-25 16:56:00
# Total: 04927 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.41% | Elapsed Time: 00:01:09:34 | Remaining Time: 00:09:58:48
# From @Almustashaar: 00444 contents of 42859
# Id: 42415 / Date: 2024-09-25 16:48:11
# Total: 04928 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.41% | Elapsed Time: 00:01:09:35 | Remaining Time: 00:09:58:47
# From @Almustashaar: 00445 contents of 42859
# Id: 42414 / Date: 2024-09-25 16:44:01
# Total: 04929 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.41% | Elapsed Time: 00:01:09:35 | Remaining Time: 00:09:58:41
# From @Almustashaar: 00446 contents of 42859
# Id: 42413 / Date: 2024-09-25 16:42:06
# Total: 04930 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.42% | Elapsed Time: 00:01:09:35 | Remaining Time: 00:09:58:35
# From @Almustashaar: 00447 contents of 42859
# Id: 42412 / Date: 2024-09-25 16:39:04
# Total: 04931 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.42% | Elapsed Time: 00:01:09:35 | Remaining Time: 00:09:58:29
# From @Almustashaar: 00448 contents of 42859
# Id: 42411 / Date: 2024-09-25 16:27:23
# Total: 04932 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.42% | Elapsed Time: 00:01:09:36 | Remaining Time: 00:09:58:24
# From @Almustashaar: 00449 contents of 42859
# Id: 42410 / Date: 2024-09-25 16:24:15
# Total: 04933 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.42% | Elapsed Time: 00:01:09:36 | Remaining Time: 00:09:58:18
# From @Almustashaar: 00450 contents of 42859
# Id: 42409 / Date: 2024-09-25 16:17:46
# Total: 04934 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.42% | Elapsed Time: 00:01:09:36 | Remaining Time: 00:09:58:13
# From @Almustashaar: 00451 contents of 42859
# Id: 42408 / Date: 2024-09-25 16:11:04
# Total: 04935 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.43% | Elapsed Time: 00:01:09:37 | Remaining Time: 00:09:58:07
# From @Almustashaar: 00452 contents of 42859
# Id: 42407 / Date: 2024-09-25 15:11:15
# Total: 04936 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.43% | Elapsed Time: 00:01:09:37 | Remaining Time: 00:09:58:01
# From @Almustashaar: 00453 contents of 42859
# Id: 42406 / Date: 2024-09-25 13:55:29
# Total: 04937 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.43% | Elapsed Time: 00:01:09:37 | Remaining Time: 00:09:57:56
# From @Almustashaar: 00454 contents of 42859
# Id: 42405 / Date: 2024-09-25 13:40:43
# Total: 04938 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.43% | Elapsed Time: 00:01:09:37 | Remaining Time: 00:09:57:50
# From @Almustashaar: 00455 contents of 42859
# Id: 42404 / Date: 2024-09-25 13:35:15
# Total: 04939 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.43% | Elapsed Time: 00:01:09:38 | Remaining Time: 00:09:57:44
# From @Almustashaar: 00456 contents of 42859
# Id: 42403 / Date: 2024-09-25 13:31:49
# Total: 04940 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.44% | Elapsed Time: 00:01:09:38 | Remaining Time: 00:09:57:40
# From @Almustashaar: 00457 contents of 42858
# Id: 42401 / Date: 2024-09-25 13:22:41
# Total: 04941 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.44% | Elapsed Time: 00:01:09:39 | Remaining Time: 00:09:57:36
# From @Almustashaar: 00458 contents of 42857
# Id: 42399 / Date: 2024-09-25 12:58:09
# Total: 04942 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.44% | Elapsed Time: 00:01:09:40 | Remaining Time: 00:09:57:32
# From @Almustashaar: 00459 contents of 42856
# Id: 42397 / Date: 2024-09-25 12:46:18
# Total: 04943 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.44% | Elapsed Time: 00:01:09:40 | Remaining Time: 00:09:57:27
# From @Almustashaar: 00460 contents of 42856
# Id: 42396 / Date: 2024-09-25 12:37:26
# Total: 04944 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.45% | Elapsed Time: 00:01:09:40 | Remaining Time: 00:09:57:21
# From @Almustashaar: 00461 contents of 42856
# Id: 42395 / Date: 2024-09-25 12:33:40
# Total: 04945 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.45% | Elapsed Time: 00:01:09:41 | Remaining Time: 00:09:57:17
# From @Almustashaar: 00462 contents of 42855
# Id: 42393 / Date: 2024-09-25 09:51:02
# Total: 04946 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.45% | Elapsed Time: 00:01:09:41 | Remaining Time: 00:09:57:11
# From @Almustashaar: 00463 contents of 42855
# Id: 42392 / Date: 2024-09-25 08:41:37
# Total: 04947 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.45% | Elapsed Time: 00:01:09:41 | Remaining Time: 00:09:57:06
# From @Almustashaar: 00464 contents of 42855
# Id: 42391 / Date: 2024-09-25 08:41:37
# Total: 04948 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.45% | Elapsed Time: 00:01:09:42 | Remaining Time: 00:09:56:58
# From @Almustashaar: 00465 contents of 42853
# Id: 42388 / Date: 2024-09-25 08:40:07
# Total: 04949 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.46% | Elapsed Time: 00:01:09:42 | Remaining Time: 00:09:56:53
# From @Almustashaar: 00466 contents of 42853
# Id: 42387 / Date: 2024-09-25 08:25:16
# Total: 04950 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.46% | Elapsed Time: 00:01:09:42 | Remaining Time: 00:09:56:47
# From @Almustashaar: 00467 contents of 42853
# Id: 42386 / Date: 2024-09-25 08:15:40
# Total: 04951 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.46% | Elapsed Time: 00:01:09:42 | Remaining Time: 00:09:56:41
# From @Almustashaar: 00468 contents of 42853
# Id: 42385 / Date: 2024-09-25 08:15:06
# Total: 04952 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.46% | Elapsed Time: 00:01:09:43 | Remaining Time: 00:09:56:36
# From @Almustashaar: 00469 contents of 42853
# Id: 42384 / Date: 2024-09-25 08:14:35
# Total: 04953 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.47% | Elapsed Time: 00:01:09:43 | Remaining Time: 00:09:56:30
# From @Almustashaar: 00470 contents of 42853
# Id: 42383 / Date: 2024-09-25 08:13:07
# Total: 04954 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.47% | Elapsed Time: 00:01:09:43 | Remaining Time: 00:09:56:24
# From @Almustashaar: 00471 contents of 42853
# Id: 42382 / Date: 2024-09-25 08:13:07
# Total: 04955 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.47% | Elapsed Time: 00:01:09:43 | Remaining Time: 00:09:56:19
# From @Almustashaar: 00472 contents of 42853
# Id: 42381 / Date: 2024-09-25 07:13:57
# Total: 04956 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.47% | Elapsed Time: 00:01:09:44 | Remaining Time: 00:09:56:13
# From @Almustashaar: 00473 contents of 42853
# Id: 42380 / Date: 2024-09-25 07:02:39
# Total: 04957 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.47% | Elapsed Time: 00:01:09:44 | Remaining Time: 00:09:56:08
# From @Almustashaar: 00474 contents of 42853
# Id: 42379 / Date: 2024-09-25 07:01:41
# Total: 04958 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.48% | Elapsed Time: 00:01:09:44 | Remaining Time: 00:09:56:02
# From @Almustashaar: 00475 contents of 42853
# Id: 42378 / Date: 2024-09-25 06:50:11
# Total: 04959 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.48% | Elapsed Time: 00:01:09:45 | Remaining Time: 00:09:55:57
# From @Almustashaar: 00476 contents of 42853
# Id: 42377 / Date: 2024-09-25 06:28:07
# Total: 04960 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.48% | Elapsed Time: 00:01:09:45 | Remaining Time: 00:09:55:52
# From @Almustashaar: 00477 contents of 42853
# Id: 42376 / Date: 2024-09-25 06:22:36
# Total: 04961 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.48% | Elapsed Time: 00:01:09:45 | Remaining Time: 00:09:55:47
# From @Almustashaar: 00478 contents of 42853
# Id: 42375 / Date: 2024-09-25 06:18:28
# Total: 04962 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.48% | Elapsed Time: 00:01:09:46 | Remaining Time: 00:09:55:45
# From @Almustashaar: 00479 contents of 42851
# Id: 42372 / Date: 2024-09-25 03:52:20
# Total: 04963 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.49% | Elapsed Time: 00:01:09:47 | Remaining Time: 00:09:55:42
# From @Almustashaar: 00480 contents of 42850
# Id: 42370 / Date: 2024-09-25 03:45:38
# Total: 04964 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.49% | Elapsed Time: 00:01:09:47 | Remaining Time: 00:09:55:37
# From @Almustashaar: 00481 contents of 42850
# Id: 42369 / Date: 2024-09-25 03:45:38
# Total: 04965 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.49% | Elapsed Time: 00:01:09:48 | Remaining Time: 00:09:55:32
# From @Almustashaar: 00482 contents of 42850
# Id: 42368 / Date: 2024-09-25 03:45:38
# Total: 04966 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.49% | Elapsed Time: 00:01:09:48 | Remaining Time: 00:09:55:27
# From @Almustashaar: 00483 contents of 42850
# Id: 42367 / Date: 2024-09-25 03:45:38
# Total: 04967 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.50% | Elapsed Time: 00:01:09:48 | Remaining Time: 00:09:55:21
# From @Almustashaar: 00484 contents of 42850
# Id: 42366 / Date: 2024-09-25 03:45:38
# Total: 04968 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.50% | Elapsed Time: 00:01:09:49 | Remaining Time: 00:09:55:16
# From @Almustashaar: 00485 contents of 42850
# Id: 42365 / Date: 2024-09-25 03:45:38
# Total: 04969 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.50% | Elapsed Time: 00:01:09:49 | Remaining Time: 00:09:55:12
# From @Almustashaar: 00486 contents of 42849
# Id: 42363 / Date: 2024-09-25 03:42:49
# Total: 04970 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.50% | Elapsed Time: 00:01:09:50 | Remaining Time: 00:09:55:11
# From @Almustashaar: 00487 contents of 42846
# Id: 42359 / Date: 2024-09-24 22:14:15
# Total: 04971 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.51% | Elapsed Time: 00:01:09:51 | Remaining Time: 00:09:55:09
# From @Almustashaar: 00488 contents of 42844
# Id: 42356 / Date: 2024-09-24 21:39:37
# Total: 04972 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.51% | Elapsed Time: 00:01:09:52 | Remaining Time: 00:09:55:05
# From @Almustashaar: 00489 contents of 42843
# Id: 42354 / Date: 2024-09-24 21:35:10
# Total: 04973 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.51% | Elapsed Time: 00:01:09:53 | Remaining Time: 00:09:55:04
# From @Almustashaar: 00490 contents of 42841
# Id: 42351 / Date: 2024-09-24 21:21:00
# Total: 04974 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.51% | Elapsed Time: 00:01:09:53 | Remaining Time: 00:09:54:58
# From @Almustashaar: 00491 contents of 42841
# Id: 42350 / Date: 2024-09-24 21:19:03
# Total: 04975 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.51% | Elapsed Time: 00:01:09:53 | Remaining Time: 00:09:54:53
# From @Almustashaar: 00492 contents of 42841
# Id: 42349 / Date: 2024-09-24 21:11:22
# Total: 04976 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.52% | Elapsed Time: 00:01:09:54 | Remaining Time: 00:09:54:47
# From @Almustashaar: 00493 contents of 42841
# Id: 42348 / Date: 2024-09-24 20:47:14
# Total: 04977 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.52% | Elapsed Time: 00:01:09:54 | Remaining Time: 00:09:54:42
# From @Almustashaar: 00494 contents of 42841
# Id: 42347 / Date: 2024-09-24 20:39:16
# Total: 04978 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.52% | Elapsed Time: 00:01:09:54 | Remaining Time: 00:09:54:36
# From @Almustashaar: 00495 contents of 42841
# Id: 42346 / Date: 2024-09-24 20:38:18
# Total: 04979 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 10.52% | Elapsed Time: 00:01:09:55 | Remaining Time: 00:09:54:33
# From @Almustashaar: 00496 contents of 42840
# Id: 42344 / Date: 2024-09-24 20:22:39
# Total: 04980 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# ...
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.40% | Elapsed Time: 00:01:12:16 | Remaining Time: 00:09:21:53
# From @Almustashaar: 00901 contents of 42763
# Id: 41862 / Date: 2024-09-20 15:07:27
# Total: 05385 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.40% | Elapsed Time: 00:01:12:17 | Remaining Time: 00:09:21:49
# From @Almustashaar: 00902 contents of 42763
# Id: 41861 / Date: 2024-09-20 14:22:50
# Total: 05386 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.40% | Elapsed Time: 00:01:12:17 | Remaining Time: 00:09:21:45
# From @Almustashaar: 00903 contents of 42762
# Id: 41859 / Date: 2024-09-20 14:21:14
# Total: 05387 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.40% | Elapsed Time: 00:01:12:17 | Remaining Time: 00:09:21:40
# From @Almustashaar: 00904 contents of 42762
# Id: 41858 / Date: 2024-09-20 14:18:08
# Total: 05388 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.41% | Elapsed Time: 00:01:12:18 | Remaining Time: 00:09:21:35
# From @Almustashaar: 00905 contents of 42762
# Id: 41857 / Date: 2024-09-20 14:16:11
# Total: 05389 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# Error processing message: 'ReactionPaid' object has no attribute 'emoticon'
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.41% | Elapsed Time: 00:01:12:18 | Remaining Time: 00:09:21:31
# From @Almustashaar: 00906 contents of 42760
# Id: 41854 / Date: 2024-09-20 13:57:01
# Total: 05390 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.41% | Elapsed Time: 00:01:12:19 | Remaining Time: 00:09:21:27
# From @Almustashaar: 00907 contents of 42760
# Id: 41853 / Date: 2024-09-20 13:55:52
# Total: 05391 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.41% | Elapsed Time: 00:01:12:19 | Remaining Time: 00:09:21:22
# From @Almustashaar: 00908 contents of 42760
# Id: 41852 / Date: 2024-09-20 13:37:36
# Total: 05392 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.42% | Elapsed Time: 00:01:12:19 | Remaining Time: 00:09:21:17
# From @Almustashaar: 00909 contents of 42760
# Id: 41851 / Date: 2024-09-20 13:37:18
# Total: 05393 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.42% | Elapsed Time: 00:01:12:20 | Remaining Time: 00:09:21:12
# From @Almustashaar: 00910 contents of 42760
# Id: 41850 / Date: 2024-09-20 13:35:19
# Total: 05394 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.42% | Elapsed Time: 00:01:12:20 | Remaining Time: 00:09:21:08
# From @Almustashaar: 00911 contents of 42760
# Id: 41849 / Date: 2024-09-20 13:21:57
# Total: 05395 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.42% | Elapsed Time: 00:01:12:20 | Remaining Time: 00:09:21:03
# From @Almustashaar: 00912 contents of 42760
# Id: 41848 / Date: 2024-09-20 13:14:33
# Total: 05396 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.42% | Elapsed Time: 00:01:12:20 | Remaining Time: 00:09:20:58
# From @Almustashaar: 00913 contents of 42760
# Id: 41847 / Date: 2024-09-20 13:12:53
# Total: 05397 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.43% | Elapsed Time: 00:01:12:21 | Remaining Time: 00:09:20:53
# From @Almustashaar: 00914 contents of 42760
# Id: 41846 / Date: 2024-09-20 13:09:22
# Total: 05398 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.43% | Elapsed Time: 00:01:12:21 | Remaining Time: 00:09:20:48
# From @Almustashaar: 00915 contents of 42760
# Id: 41845 / Date: 2024-09-20 13:06:39
# Total: 05399 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.43% | Elapsed Time: 00:01:12:21 | Remaining Time: 00:09:20:43
# From @Almustashaar: 00916 contents of 42760
# Id: 41844 / Date: 2024-09-20 13:06:39
# Total: 05400 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.43% | Elapsed Time: 00:01:12:22 | Remaining Time: 00:09:20:38
# From @Almustashaar: 00917 contents of 42760
# Id: 41843 / Date: 2024-09-20 13:06:39
# Total: 05401 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.43% | Elapsed Time: 00:01:12:22 | Remaining Time: 00:09:20:34
# From @Almustashaar: 00918 contents of 42760
# Id: 41842 / Date: 2024-09-20 13:06:39
# Total: 05402 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.44% | Elapsed Time: 00:01:12:22 | Remaining Time: 00:09:20:29
# From @Almustashaar: 00919 contents of 42760
# Id: 41841 / Date: 2024-09-20 13:05:32
# Total: 05403 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.44% | Elapsed Time: 00:01:12:22 | Remaining Time: 00:09:20:24
# From @Almustashaar: 00920 contents of 42760
# Id: 41840 / Date: 2024-09-20 11:08:51
# Total: 05404 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.44% | Elapsed Time: 00:01:12:23 | Remaining Time: 00:09:20:19
# From @Almustashaar: 00921 contents of 42760
# Id: 41839 / Date: 2024-09-20 11:02:13
# Total: 05405 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.44% | Elapsed Time: 00:01:12:23 | Remaining Time: 00:09:20:14
# From @Almustashaar: 00922 contents of 42760
# Id: 41838 / Date: 2024-09-20 10:40:52
# Total: 05406 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.44% | Elapsed Time: 00:01:12:23 | Remaining Time: 00:09:20:09
# From @Almustashaar: 00923 contents of 42760
# Id: 41837 / Date: 2024-09-20 10:17:22
# Total: 05407 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.45% | Elapsed Time: 00:01:12:24 | Remaining Time: 00:09:20:04
# From @Almustashaar: 00924 contents of 42759
# Id: 41835 / Date: 2024-09-20 10:09:33
# Total: 05408 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.45% | Elapsed Time: 00:01:12:24 | Remaining Time: 00:09:20:00
# From @Almustashaar: 00925 contents of 42759
# Id: 41834 / Date: 2024-09-20 10:08:01
# Total: 05409 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.45% | Elapsed Time: 00:01:12:24 | Remaining Time: 00:09:19:55
# From @Almustashaar: 00926 contents of 42759
# Id: 41833 / Date: 2024-09-20 10:07:02
# Total: 05410 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.45% | Elapsed Time: 00:01:12:24 | Remaining Time: 00:09:19:50
# From @Almustashaar: 00927 contents of 42759
# Id: 41832 / Date: 2024-09-20 07:17:04
# Total: 05411 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.46% | Elapsed Time: 00:01:12:25 | Remaining Time: 00:09:19:45
# From @Almustashaar: 00928 contents of 42759
# Id: 41831 / Date: 2024-09-20 07:12:15
# Total: 05412 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.46% | Elapsed Time: 00:01:12:25 | Remaining Time: 00:09:19:41
# From @Almustashaar: 00929 contents of 42759
# Id: 41830 / Date: 2024-09-20 06:56:14
# Total: 05413 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.46% | Elapsed Time: 00:01:12:25 | Remaining Time: 00:09:19:36
# From @Almustashaar: 00930 contents of 42759
# Id: 41829 / Date: 2024-09-20 06:54:59
# Total: 05414 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.46% | Elapsed Time: 00:01:12:26 | Remaining Time: 00:09:19:31
# From @Almustashaar: 00931 contents of 42759
# Id: 41828 / Date: 2024-09-20 06:54:12
# Total: 05415 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.46% | Elapsed Time: 00:01:12:26 | Remaining Time: 00:09:19:26
# From @Almustashaar: 00932 contents of 42759
# Id: 41827 / Date: 2024-09-20 06:53:14
# Total: 05416 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.47% | Elapsed Time: 00:01:12:26 | Remaining Time: 00:09:19:21
# From @Almustashaar: 00933 contents of 42759
# Id: 41826 / Date: 2024-09-20 06:49:32
# Total: 05417 contents until now
# --------------------------------------------------------------------------------
#
#
# Error processing comments: The message ID used in the peer was invalid (caused by GetRepliesRequest)
# --------------------------------------------------------------------------------
# Progress: 11.47% | Elapsed Time: 00:01:12:26 | Remaining Time: 00:09:19:16
# From @Almustashaar: 00934 contents of 42759
# Id: 41825 / Date: 2024-09-20 06:43:37
# Total: 05418 contents until now
# --------------------------------------------------------------------------------
#
#
#
#
# ##### @Almustashaar was ok with 00934 posts #####
#
#
#
# --------------------------------------------------
# #Concluded! #05418 posts were scraped!
# --------------------------------------------------
